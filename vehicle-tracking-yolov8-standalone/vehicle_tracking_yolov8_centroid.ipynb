# %%
# pip install opencv-python torch torchvision numpy matplotlib ultralytics

# %%
from scipy.spatial import distance as dist
from collections import OrderedDict
import numpy as np
import cv2
from ultralytics import YOLO
from collections import defaultdict
import matplotlib.pyplot as plt

# %%
class CentroidTracker:
    def __init__(self, max_disappeared=50):
        self.next_object_id = 0
        self.objects = OrderedDict()
        self.disappeared = OrderedDict()
        self.max_disappeared = max_disappeared

    def register(self, centroid):
        self.objects[self.next_object_id] = centroid
        self.disappeared[self.next_object_id] = 0
        self.next_object_id += 1

    def deregister(self, object_id):
        del self.objects[object_id]
        del self.disappeared[object_id]

    def update(self, rects):
        if len(rects) == 0:
            for object_id in list(self.disappeared.keys()):
                self.disappeared[object_id] += 1
                if self.disappeared[object_id] > self.max_disappeared:
                    self.deregister(object_id)
            return self.objects

        input_centroids = np.zeros((len(rects), 2), dtype="int")
        for (i, (x1, y1, x2, y2)) in enumerate(rects):
            cX = int((x1 + x2) / 2.0)
            cY = int((y1 + y2) / 2.0)
            input_centroids[i] = (cX, cY)

        if len(self.objects) == 0:
            for i in range(0, len(input_centroids)):
                self.register(input_centroids[i])
        else:
            object_ids = list(self.objects.keys())
            object_centroids = list(self.objects.values())

            D = dist.cdist(np.array(object_centroids), input_centroids)
            rows = D.min(axis=1).argsort()
            cols = D.argmin(axis=1)[rows]

            used_rows, used_cols = set(), set()

            for (row, col) in zip(rows, cols):
                if row in used_rows or col in used_cols:
                    continue
                object_id = object_ids[row]
                self.objects[object_id] = input_centroids[col]
                self.disappeared[object_id] = 0
                used_rows.add(row)
                used_cols.add(col)

            unused_rows = set(range(0, D.shape[0])).difference(used_rows)
            unused_cols = set(range(0, D.shape[1])).difference(used_cols)

            for row in unused_rows:
                object_id = object_ids[row]
                self.disappeared[object_id] += 1
                if self.disappeared[object_id] > self.max_disappeared:
                    self.deregister(object_id)

            for col in unused_cols:
                self.register(input_centroids[col])

        return self.objects

# %%
# Initialize model and tracker
model = YOLO("yolov8n.pt")
ct = CentroidTracker()

# %%
vehicle_classes = {2: "car", 3: "motorcycle", 5: "bus", 7: "truck"}

# %%
cap = cv2.VideoCapture("traffic.mp4")

# %%
frame_count = 0
total_unique_ids = set()
class_id_map = {}

# %%
# Initialize a dictionary to hold the total count for each vehicle type
vehicle_counts = defaultdict(int)

# %%
while True:
    ret, frame = cap.read()
    if not ret:
        break
    frame_count += 1

    results = model(frame)[0]

    rects = []
    boxes_info = []

    for box in results.boxes:
        cls_id = int(box.cls)
        if cls_id in vehicle_classes:
            x1, y1, x2, y2 = map(int, box.xyxy[0])
            rects.append((x1, y1, x2, y2))
            boxes_info.append(((x1, y1, x2, y2), cls_id))

    objects = ct.update(rects)

    per_frame_stats = defaultdict(int)

    for object_id, centroid in objects.items():
        if object_id < len(boxes_info):
            (x1, y1, x2, y2), cls_id = boxes_info[object_id]
            class_name = vehicle_classes[cls_id]
            per_frame_stats[class_name] += 1
            total_unique_ids.add(object_id)
            class_id_map[object_id] = class_name

            # Draw box and ID
            cv2.rectangle(frame, (x1, y1), (x2, y2), (255, 0, 0), 2)
            cv2.putText(frame, f"ID:{object_id} {class_name}", (x1, y1 - 5),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 0), 2)

    # Update the total counts across all frames
    for vehicle_type, count in per_frame_stats.items():
        vehicle_counts[vehicle_type] += count

    # Display counts
    y_offset = 20
    for cls, count in per_frame_stats.items():
        cv2.putText(frame, f"{cls}: {count}", (10, y_offset),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 255), 2)
        y_offset += 25

    cv2.putText(frame, f"Unique Vehicles: {len(set(class_id_map.keys()))}", (10, y_offset),
                cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)

    resized_frame = cv2.resize(frame, (800, 450))  # or (640, 360)
    cv2.imshow("Vehicle Detection", resized_frame)
    
    if cv2.waitKey(1) == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 10 cars, 1 bus, 3 trucks, 89.2ms
# Speed: 6.6ms preprocess, 89.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 73.6ms
# Speed: 5.8ms preprocess, 73.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 bus, 3 trucks, 56.4ms
# Speed: 2.2ms preprocess, 56.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 4 trucks, 53.5ms
# Speed: 2.4ms preprocess, 53.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 3 trucks, 53.0ms
# Speed: 4.2ms preprocess, 53.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 trucks, 52.2ms
# Speed: 2.3ms preprocess, 52.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 3 trucks, 57.1ms
# Speed: 2.2ms preprocess, 57.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 4 trucks, 57.3ms
# Speed: 3.1ms preprocess, 57.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 3 trucks, 51.6ms
# Speed: 2.2ms preprocess, 51.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 3 trucks, 52.0ms
# Speed: 2.2ms preprocess, 52.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 3 trucks, 54.9ms
# Speed: 2.3ms preprocess, 54.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 4 trucks, 64.5ms
# Speed: 2.8ms preprocess, 64.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 buss, 3 trucks, 54.9ms
# Speed: 2.6ms preprocess, 54.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 3 trucks, 51.1ms
# Speed: 3.5ms preprocess, 51.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 3 trucks, 56.1ms
# Speed: 2.4ms preprocess, 56.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 3 trucks, 69.2ms
# Speed: 2.3ms preprocess, 69.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 4 trucks, 50.7ms
# Speed: 2.1ms preprocess, 50.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 4 trucks, 53.9ms
# Speed: 2.2ms preprocess, 53.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 buss, 4 trucks, 49.0ms
# Speed: 2.3ms preprocess, 49.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 4 trucks, 56.3ms
# Speed: 2.4ms preprocess, 56.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 4 trucks, 67.2ms
# Speed: 4.1ms preprocess, 67.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 3 trucks, 62.3ms
# Speed: 2.8ms preprocess, 62.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 4 trucks, 64.5ms
# Speed: 2.6ms preprocess, 64.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 4 trucks, 58.5ms
# Speed: 2.8ms preprocess, 58.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 4 trucks, 56.2ms
# Speed: 2.2ms preprocess, 56.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 4 trucks, 52.5ms
# Speed: 2.1ms preprocess, 52.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 4 trucks, 50.8ms
# Speed: 2.1ms preprocess, 50.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 trucks, 51.7ms
# Speed: 2.2ms preprocess, 51.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 4 trucks, 48.3ms
# Speed: 2.3ms preprocess, 48.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 4 trucks, 47.9ms
# Speed: 2.2ms preprocess, 47.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 trucks, 53.8ms
# Speed: 2.5ms preprocess, 53.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 trucks, 49.3ms
# Speed: 2.2ms preprocess, 49.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 trucks, 48.7ms
# Speed: 3.0ms preprocess, 48.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 trucks, 54.6ms
# Speed: 2.2ms preprocess, 54.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 trucks, 51.1ms
# Speed: 3.6ms preprocess, 51.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 4 trucks, 61.9ms
# Speed: 2.8ms preprocess, 61.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 4 trucks, 70.5ms
# Speed: 2.5ms preprocess, 70.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 trucks, 46.0ms
# Speed: 3.0ms preprocess, 46.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 4 trucks, 50.2ms
# Speed: 2.5ms preprocess, 50.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 60.0ms
# Speed: 2.9ms preprocess, 60.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 51.4ms
# Speed: 2.6ms preprocess, 51.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 5 trucks, 48.9ms
# Speed: 2.4ms preprocess, 48.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 48.6ms
# Speed: 2.1ms preprocess, 48.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 49.1ms
# Speed: 2.2ms preprocess, 49.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 48.9ms
# Speed: 2.7ms preprocess, 48.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 5 trucks, 55.5ms
# Speed: 2.2ms preprocess, 55.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 5 trucks, 49.2ms
# Speed: 2.4ms preprocess, 49.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 5 trucks, 53.3ms
# Speed: 2.0ms preprocess, 53.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 46.7ms
# Speed: 2.1ms preprocess, 46.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 5 trucks, 49.9ms
# Speed: 2.7ms preprocess, 49.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 5 trucks, 49.4ms
# Speed: 2.5ms preprocess, 49.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 5 trucks, 47.4ms
# Speed: 2.4ms preprocess, 47.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 5 trucks, 48.1ms
# Speed: 2.8ms preprocess, 48.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 5 trucks, 45.9ms
# Speed: 2.5ms preprocess, 45.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 49.6ms
# Speed: 2.5ms preprocess, 49.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 5 trucks, 56.3ms
# Speed: 2.9ms preprocess, 56.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 5 trucks, 60.0ms
# Speed: 3.0ms preprocess, 60.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 5 trucks, 49.2ms
# Speed: 2.7ms preprocess, 49.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 5 trucks, 49.1ms
# Speed: 2.4ms preprocess, 49.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 58.2ms
# Speed: 2.9ms preprocess, 58.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 5 trucks, 47.8ms
# Speed: 2.5ms preprocess, 47.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 buss, 5 trucks, 52.0ms
# Speed: 3.1ms preprocess, 52.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 5 trucks, 57.6ms
# Speed: 2.5ms preprocess, 57.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 buss, 5 trucks, 53.3ms
# Speed: 2.2ms preprocess, 53.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 buss, 5 trucks, 48.0ms
# Speed: 3.0ms preprocess, 48.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 buss, 5 trucks, 51.1ms
# Speed: 2.8ms preprocess, 51.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 5 trucks, 54.0ms
# Speed: 2.9ms preprocess, 54.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 53.0ms
# Speed: 2.4ms preprocess, 53.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 51.4ms
# Speed: 3.0ms preprocess, 51.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 51.9ms
# Speed: 2.3ms preprocess, 51.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 53.2ms
# Speed: 2.4ms preprocess, 53.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 5 trucks, 57.2ms
# Speed: 3.1ms preprocess, 57.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 48.9ms
# Speed: 3.1ms preprocess, 48.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 5 trucks, 53.1ms
# Speed: 2.5ms preprocess, 53.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 51.2ms
# Speed: 2.8ms preprocess, 51.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 50.1ms
# Speed: 2.9ms preprocess, 50.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 5 trucks, 66.8ms
# Speed: 3.7ms preprocess, 66.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 5 trucks, 46.8ms
# Speed: 2.0ms preprocess, 46.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 5 trucks, 50.2ms
# Speed: 2.2ms preprocess, 50.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 5 trucks, 74.3ms
# Speed: 2.7ms preprocess, 74.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 5 trucks, 53.8ms
# Speed: 2.3ms preprocess, 53.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 5 trucks, 51.0ms
# Speed: 3.0ms preprocess, 51.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 5 trucks, 54.8ms
# Speed: 2.2ms preprocess, 54.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 5 trucks, 44.5ms
# Speed: 2.2ms preprocess, 44.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 5 trucks, 56.2ms
# Speed: 2.5ms preprocess, 56.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 5 trucks, 48.2ms
# Speed: 2.2ms preprocess, 48.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 5 trucks, 50.3ms
# Speed: 2.4ms preprocess, 50.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 5 trucks, 48.7ms
# Speed: 2.3ms preprocess, 48.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 5 trucks, 60.5ms
# Speed: 2.5ms preprocess, 60.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 5 trucks, 54.5ms
# Speed: 2.8ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 5 trucks, 54.8ms
# Speed: 2.7ms preprocess, 54.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 5 trucks, 57.2ms
# Speed: 3.1ms preprocess, 57.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 5 trucks, 57.2ms
# Speed: 2.9ms preprocess, 57.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 5 trucks, 57.3ms
# Speed: 2.6ms preprocess, 57.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 5 trucks, 67.0ms
# Speed: 2.7ms preprocess, 67.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 5 trucks, 55.5ms
# Speed: 2.4ms preprocess, 55.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 5 trucks, 57.0ms
# Speed: 2.6ms preprocess, 57.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 5 trucks, 52.8ms
# Speed: 2.4ms preprocess, 52.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 4 trucks, 53.4ms
# Speed: 2.1ms preprocess, 53.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 4 trucks, 53.7ms
# Speed: 2.2ms preprocess, 53.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 5 trucks, 60.8ms
# Speed: 3.3ms preprocess, 60.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 5 trucks, 68.7ms
# Speed: 2.8ms preprocess, 68.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 5 trucks, 61.7ms
# Speed: 2.5ms preprocess, 61.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 5 trucks, 69.4ms
# Speed: 3.3ms preprocess, 69.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 5 trucks, 66.2ms
# Speed: 2.8ms preprocess, 66.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 83.8ms
# Speed: 3.0ms preprocess, 83.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 5 trucks, 64.3ms
# Speed: 2.8ms preprocess, 64.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 68.7ms
# Speed: 3.3ms preprocess, 68.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 5 trucks, 75.3ms
# Speed: 3.0ms preprocess, 75.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 5 trucks, 67.0ms
# Speed: 3.3ms preprocess, 67.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 trucks, 66.4ms
# Speed: 2.9ms preprocess, 66.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 4 trucks, 63.5ms
# Speed: 2.8ms preprocess, 63.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 trucks, 64.7ms
# Speed: 2.7ms preprocess, 64.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 trucks, 66.0ms
# Speed: 3.4ms preprocess, 66.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 4 trucks, 92.6ms
# Speed: 3.2ms preprocess, 92.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 4 trucks, 75.3ms
# Speed: 4.6ms preprocess, 75.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 trucks, 77.4ms
# Speed: 2.7ms preprocess, 77.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 trucks, 65.9ms
# Speed: 3.0ms preprocess, 65.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 trucks, 64.5ms
# Speed: 2.8ms preprocess, 64.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 trucks, 67.0ms
# Speed: 3.2ms preprocess, 67.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 69.2ms
# Speed: 2.5ms preprocess, 69.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 trucks, 66.3ms
# Speed: 2.7ms preprocess, 66.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 trucks, 61.8ms
# Speed: 2.8ms preprocess, 61.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 62.0ms
# Speed: 2.6ms preprocess, 62.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 3 trucks, 61.9ms
# Speed: 3.0ms preprocess, 61.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 51.6ms
# Speed: 2.5ms preprocess, 51.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 64.0ms
# Speed: 2.8ms preprocess, 64.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 64.3ms
# Speed: 2.5ms preprocess, 64.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 70.2ms
# Speed: 2.7ms preprocess, 70.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 3 trucks, 62.8ms
# Speed: 2.8ms preprocess, 62.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 1 train, 2 trucks, 54.5ms
# Speed: 2.4ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 train, 2 trucks, 68.1ms
# Speed: 2.2ms preprocess, 68.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 train, 2 trucks, 50.9ms
# Speed: 2.6ms preprocess, 50.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 train, 2 trucks, 57.8ms
# Speed: 2.5ms preprocess, 57.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 1 train, 2 trucks, 55.9ms
# Speed: 2.6ms preprocess, 55.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 1 train, 2 trucks, 65.4ms
# Speed: 2.9ms preprocess, 65.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 1 train, 2 trucks, 62.7ms
# Speed: 3.0ms preprocess, 62.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 1 train, 2 trucks, 60.6ms
# Speed: 3.8ms preprocess, 60.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 train, 2 trucks, 64.4ms
# Speed: 3.2ms preprocess, 64.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 1 train, 2 trucks, 71.1ms
# Speed: 2.6ms preprocess, 71.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 1 train, 2 trucks, 66.7ms
# Speed: 2.6ms preprocess, 66.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 1 train, 2 trucks, 70.9ms
# Speed: 2.8ms preprocess, 70.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 1 train, 2 trucks, 68.9ms
# Speed: 3.2ms preprocess, 68.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 4 trucks, 68.3ms
# Speed: 2.8ms preprocess, 68.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 1 train, 2 trucks, 70.7ms
# Speed: 3.4ms preprocess, 70.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 2 trucks, 70.9ms
# Speed: 3.7ms preprocess, 70.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 2 trucks, 71.4ms
# Speed: 3.6ms preprocess, 71.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 2 trucks, 67.7ms
# Speed: 2.9ms preprocess, 67.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 2 trucks, 65.1ms
# Speed: 3.0ms preprocess, 65.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 2 trucks, 67.1ms
# Speed: 3.0ms preprocess, 67.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 4 trucks, 62.9ms
# Speed: 2.7ms preprocess, 62.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 buss, 3 trucks, 68.1ms
# Speed: 2.6ms preprocess, 68.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 buss, 2 trucks, 76.4ms
# Speed: 5.4ms preprocess, 76.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 buss, 3 trucks, 68.4ms
# Speed: 3.4ms preprocess, 68.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 2 trucks, 70.3ms
# Speed: 3.0ms preprocess, 70.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 buss, 1 train, 3 trucks, 70.2ms
# Speed: 3.2ms preprocess, 70.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 buss, 2 trucks, 71.5ms
# Speed: 3.0ms preprocess, 71.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 buss, 4 trucks, 60.6ms
# Speed: 2.8ms preprocess, 60.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 4 trucks, 52.8ms
# Speed: 2.4ms preprocess, 52.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 2 trucks, 61.7ms
# Speed: 2.4ms preprocess, 61.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 trucks, 69.6ms
# Speed: 3.1ms preprocess, 69.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 5 trucks, 74.0ms
# Speed: 3.7ms preprocess, 74.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 4 trucks, 63.1ms
# Speed: 2.8ms preprocess, 63.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 4 trucks, 57.9ms
# Speed: 3.1ms preprocess, 57.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 3 trucks, 68.5ms
# Speed: 2.8ms preprocess, 68.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 3 trucks, 64.6ms
# Speed: 3.1ms preprocess, 64.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 3 trucks, 60.1ms
# Speed: 2.4ms preprocess, 60.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 3 trucks, 63.6ms
# Speed: 2.3ms preprocess, 63.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 3 trucks, 55.5ms
# Speed: 2.4ms preprocess, 55.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 3 trucks, 66.3ms
# Speed: 3.2ms preprocess, 66.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 4 trucks, 58.1ms
# Speed: 2.7ms preprocess, 58.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 3 trucks, 57.5ms
# Speed: 3.0ms preprocess, 57.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 2 trucks, 50.9ms
# Speed: 2.5ms preprocess, 50.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 3 trucks, 58.2ms
# Speed: 3.0ms preprocess, 58.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 3 trucks, 58.2ms
# Speed: 3.3ms preprocess, 58.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 3 trucks, 56.9ms
# Speed: 3.0ms preprocess, 56.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 3 trucks, 58.4ms
# Speed: 2.4ms preprocess, 58.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 3 trucks, 58.1ms
# Speed: 3.2ms preprocess, 58.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 4 trucks, 68.1ms
# Speed: 2.6ms preprocess, 68.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 buss, 3 trucks, 60.3ms
# Speed: 2.6ms preprocess, 60.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 buss, 3 trucks, 62.4ms
# Speed: 2.8ms preprocess, 62.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 buss, 3 trucks, 61.7ms
# Speed: 3.2ms preprocess, 61.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 buss, 3 trucks, 55.4ms
# Speed: 2.7ms preprocess, 55.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 buss, 3 trucks, 44.9ms
# Speed: 2.4ms preprocess, 44.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 buss, 3 trucks, 47.9ms
# Speed: 2.7ms preprocess, 47.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 4 buss, 3 trucks, 47.6ms
# Speed: 2.4ms preprocess, 47.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 3 trucks, 63.4ms
# Speed: 2.4ms preprocess, 63.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 3 trucks, 61.2ms
# Speed: 2.3ms preprocess, 61.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 buss, 3 trucks, 58.7ms
# Speed: 2.8ms preprocess, 58.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 buss, 3 trucks, 61.8ms
# Speed: 2.7ms preprocess, 61.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 buss, 3 trucks, 50.1ms
# Speed: 2.3ms preprocess, 50.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 3 buss, 3 trucks, 47.5ms
# Speed: 2.6ms preprocess, 47.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 buss, 3 trucks, 46.7ms
# Speed: 2.5ms preprocess, 46.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 buss, 3 trucks, 50.1ms
# Speed: 2.4ms preprocess, 50.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 3 buss, 4 trucks, 64.8ms
# Speed: 2.7ms preprocess, 64.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 3 buss, 3 trucks, 51.0ms
# Speed: 2.4ms preprocess, 51.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 buss, 5 trucks, 48.0ms
# Speed: 3.2ms preprocess, 48.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 3 buss, 3 trucks, 49.7ms
# Speed: 2.6ms preprocess, 49.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 3 buss, 5 trucks, 46.9ms
# Speed: 2.2ms preprocess, 46.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 3 buss, 3 trucks, 50.0ms
# Speed: 2.8ms preprocess, 50.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 buss, 3 trucks, 48.8ms
# Speed: 3.0ms preprocess, 48.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2 buss, 3 trucks, 49.6ms
# Speed: 3.0ms preprocess, 49.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 3 buss, 3 trucks, 69.4ms
# Speed: 2.7ms preprocess, 69.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 3 buss, 3 trucks, 57.4ms
# Speed: 3.3ms preprocess, 57.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 4 buss, 3 trucks, 67.7ms
# Speed: 2.7ms preprocess, 67.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2 buss, 4 trucks, 68.5ms
# Speed: 3.2ms preprocess, 68.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 3 buss, 3 trucks, 72.6ms
# Speed: 3.4ms preprocess, 72.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 4 buss, 3 trucks, 62.2ms
# Speed: 4.3ms preprocess, 62.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 5 buss, 2 trucks, 59.1ms
# Speed: 3.3ms preprocess, 59.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 5 buss, 3 trucks, 68.3ms
# Speed: 2.7ms preprocess, 68.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 4 buss, 3 trucks, 62.6ms
# Speed: 2.5ms preprocess, 62.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 4 buss, 3 trucks, 64.6ms
# Speed: 2.5ms preprocess, 64.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 buss, 3 trucks, 59.2ms
# Speed: 3.1ms preprocess, 59.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 buss, 3 trucks, 57.8ms
# Speed: 3.0ms preprocess, 57.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 4 buss, 3 trucks, 60.0ms
# Speed: 2.6ms preprocess, 60.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 4 buss, 3 trucks, 55.6ms
# Speed: 2.4ms preprocess, 55.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 4 buss, 3 trucks, 63.9ms
# Speed: 3.1ms preprocess, 63.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 3 buss, 3 trucks, 48.3ms
# Speed: 2.3ms preprocess, 48.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 3 trucks, 57.4ms
# Speed: 2.3ms preprocess, 57.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 3 trucks, 49.3ms
# Speed: 2.6ms preprocess, 49.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 buss, 2 trucks, 1 stop sign, 53.8ms
# Speed: 2.8ms preprocess, 53.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 6 cars, 2 buss, 2 trucks, 1 stop sign, 53.8ms
# Speed: 3.2ms preprocess, 53.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 3 trucks, 1 stop sign, 53.6ms
# Speed: 2.4ms preprocess, 53.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 buss, 3 trucks, 1 stop sign, 64.2ms
# Speed: 2.5ms preprocess, 64.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 buss, 2 trucks, 1 stop sign, 59.7ms
# Speed: 2.3ms preprocess, 59.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 2 trucks, 48.6ms
# Speed: 2.6ms preprocess, 48.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 buss, 3 trucks, 46.6ms
# Speed: 2.3ms preprocess, 46.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 buss, 5 trucks, 48.2ms
# Speed: 2.4ms preprocess, 48.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 buss, 3 trucks, 50.6ms
# Speed: 2.6ms preprocess, 50.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 3 buss, 4 trucks, 66.9ms
# Speed: 3.0ms preprocess, 66.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 3 buss, 3 trucks, 49.6ms
# Speed: 2.7ms preprocess, 49.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 3 buss, 2 trucks, 50.9ms
# Speed: 2.4ms preprocess, 50.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 4 trucks, 57.0ms
# Speed: 2.7ms preprocess, 57.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 4 trucks, 55.0ms
# Speed: 2.5ms preprocess, 55.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 5 trucks, 61.8ms
# Speed: 3.2ms preprocess, 61.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 5 trucks, 64.3ms
# Speed: 2.4ms preprocess, 64.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 5 trucks, 55.3ms
# Speed: 3.2ms preprocess, 55.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 5 trucks, 51.1ms
# Speed: 3.2ms preprocess, 51.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 4 trucks, 49.4ms
# Speed: 2.4ms preprocess, 49.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 4 trucks, 49.6ms
# Speed: 2.5ms preprocess, 49.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 4 trucks, 50.0ms
# Speed: 2.6ms preprocess, 50.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 4 trucks, 66.7ms
# Speed: 3.2ms preprocess, 66.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 4 trucks, 49.5ms
# Speed: 3.0ms preprocess, 49.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 buss, 3 trucks, 54.4ms
# Speed: 2.4ms preprocess, 54.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 3 buss, 4 trucks, 54.3ms
# Speed: 3.2ms preprocess, 54.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 4 trucks, 54.6ms
# Speed: 2.8ms preprocess, 54.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 5 trucks, 54.2ms
# Speed: 2.5ms preprocess, 54.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 2 trucks, 66.7ms
# Speed: 2.4ms preprocess, 66.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 buss, 4 trucks, 51.1ms
# Speed: 3.3ms preprocess, 51.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 3 buss, 5 trucks, 50.5ms
# Speed: 3.2ms preprocess, 50.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 buss, 5 trucks, 48.7ms
# Speed: 2.5ms preprocess, 48.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 buss, 4 trucks, 49.5ms
# Speed: 2.2ms preprocess, 49.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 buss, 4 trucks, 50.3ms
# Speed: 3.1ms preprocess, 50.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 buss, 4 trucks, 66.8ms
# Speed: 2.9ms preprocess, 66.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 buss, 4 trucks, 56.6ms
# Speed: 2.4ms preprocess, 56.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 buss, 4 trucks, 50.5ms
# Speed: 2.3ms preprocess, 50.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 3 trucks, 63.9ms
# Speed: 2.9ms preprocess, 63.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 4 trucks, 67.3ms
# Speed: 3.2ms preprocess, 67.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 buss, 2 trucks, 52.5ms
# Speed: 2.5ms preprocess, 52.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 buss, 3 trucks, 63.2ms
# Speed: 2.5ms preprocess, 63.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 3 trucks, 51.6ms
# Speed: 2.7ms preprocess, 51.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 buss, 2 trucks, 50.4ms
# Speed: 3.2ms preprocess, 50.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 buss, 2 trucks, 48.8ms
# Speed: 2.4ms preprocess, 48.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 buss, 3 trucks, 46.8ms
# Speed: 2.4ms preprocess, 46.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 3 trucks, 59.7ms
# Speed: 5.3ms preprocess, 59.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 4 trucks, 66.9ms
# Speed: 2.8ms preprocess, 66.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 buss, 3 trucks, 55.0ms
# Speed: 2.9ms preprocess, 55.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 2 trucks, 50.8ms
# Speed: 3.1ms preprocess, 50.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 buss, 2 trucks, 49.3ms
# Speed: 2.5ms preprocess, 49.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 3 trucks, 50.4ms
# Speed: 2.7ms preprocess, 50.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 buss, 3 trucks, 48.3ms
# Speed: 2.2ms preprocess, 48.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 3 trucks, 63.9ms
# Speed: 3.5ms preprocess, 63.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 3 trucks, 51.0ms
# Speed: 3.0ms preprocess, 51.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 2 trucks, 49.6ms
# Speed: 2.6ms preprocess, 49.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 4 trucks, 49.3ms
# Speed: 2.4ms preprocess, 49.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 4 trucks, 47.2ms
# Speed: 2.4ms preprocess, 47.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 4 trucks, 50.7ms
# Speed: 3.2ms preprocess, 50.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 4 trucks, 67.9ms
# Speed: 2.8ms preprocess, 67.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 3 trucks, 53.9ms
# Speed: 2.5ms preprocess, 53.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 trucks, 57.9ms
# Speed: 2.3ms preprocess, 57.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 3 trucks, 65.5ms
# Speed: 3.8ms preprocess, 65.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 2 trucks, 48.3ms
# Speed: 2.5ms preprocess, 48.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 2 trucks, 47.8ms
# Speed: 2.4ms preprocess, 47.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 2 trucks, 65.1ms
# Speed: 2.6ms preprocess, 65.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 2 trucks, 51.4ms
# Speed: 2.5ms preprocess, 51.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 2 trucks, 49.6ms
# Speed: 2.5ms preprocess, 49.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 2 trucks, 47.3ms
# Speed: 2.3ms preprocess, 47.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 buss, 2 trucks, 49.0ms
# Speed: 2.4ms preprocess, 49.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 buss, 2 trucks, 50.6ms
# Speed: 3.3ms preprocess, 50.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 2 trucks, 65.9ms
# Speed: 2.7ms preprocess, 65.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 buss, 2 trucks, 53.3ms
# Speed: 3.4ms preprocess, 53.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 5 trucks, 56.0ms
# Speed: 3.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 4 trucks, 51.8ms
# Speed: 2.7ms preprocess, 51.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 4 trucks, 51.8ms
# Speed: 2.8ms preprocess, 51.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 4 trucks, 75.5ms
# Speed: 3.3ms preprocess, 75.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 buss, 2 trucks, 61.2ms
# Speed: 2.6ms preprocess, 61.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 2 trucks, 54.0ms
# Speed: 3.7ms preprocess, 54.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 buss, 2 trucks, 53.4ms
# Speed: 2.8ms preprocess, 53.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 buss, 3 trucks, 55.7ms
# Speed: 2.7ms preprocess, 55.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 buss, 2 trucks, 68.0ms
# Speed: 3.4ms preprocess, 68.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 buss, 3 trucks, 48.2ms
# Speed: 2.4ms preprocess, 48.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 buss, 2 trucks, 48.4ms
# Speed: 2.3ms preprocess, 48.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 buss, 2 trucks, 61.1ms
# Speed: 2.8ms preprocess, 61.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 buss, 2 trucks, 46.9ms
# Speed: 2.8ms preprocess, 46.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 4 trucks, 62.6ms
# Speed: 2.9ms preprocess, 62.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 3 trucks, 48.3ms
# Speed: 2.4ms preprocess, 48.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 4 trucks, 45.1ms
# Speed: 2.7ms preprocess, 45.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)

# %%
# Print total unique vehicles
print(f"Total unique vehicles detected: {len(total_unique_ids)}")
# Out:
# Total unique vehicles detected: 14
